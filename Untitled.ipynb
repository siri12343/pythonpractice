# %%
a,b=5,8
a,b=b,a
print(a,b)
# Out:
# 8 5

# %%
s=int(input("enter a num1"))
d=int(input("enter a num2"))
a=s+d
print(a)
a=s-d
print(a)
a=s*d
print(a)
a=s/d
print(a)
a=s%d
print(a)
# Out:
# enter a num12
# enter a num26
# 8
# -4
# 12
# 0.3333333333333333
# 2

# %% [markdown]
# ## strings
# - colection of characters
# - python has a advantage it can able to store multilines
# - in python two ways to accessing string values by using idex position
#    - fwd indexing
#    - backward indexing

# %%
s1="python workshop"
s2="mstp prgram"

# %%
s1
s2
# Out:
# 'mstp prgram'

# %%
s1,s2
# Out:
# ('python workshop', 'mstp prgram')

# %%
len(s1)
# Out:
# 15

# %%
txt="""
nkjfk
bjgsif
vhjd
hgsfj
"""
print(txt)
len(txt)
# Out:
# nkjfk
# bjgsif
# vhjd
# hgsfj
# 25

# %%
s1
# Out:
# 'python workshop'

# %%
s1[4]
# Out:
# 'o'

# %%
s1[-1]
# Out:
# 'p'

# %%
s1[0:6]
# Out:
# 'python'

# %%
s1[3:5]
# Out:
# 'ho'

# %%
s1[:5]
# Out:
# 'pytho'

# %%
s1[2:]
# Out:
# 'thon workshop'

# %%
s1[0:3]
# Out:
# 'pyt'

# %%
s1[1::2]
# Out:
# 'yhnwrso'

# %%
s1[0::2]
# Out:
# 'pto okhp'

# %%
s1[-1:-8]
s1[::-1]
# Out:
# 'pohskrow nohtyp'

# %%
s1[-1:]
# Out:
# 'p'

# %%
s1[::-2]
s1[-2::-2]
# Out:
# 'osrwnhy'

# %%
s2=s1[::-1]
s2
# Out:
# 'pohskrow nohtyp'

# %%
name=input("enter a string")
name1=name[::-1]
if name==name1:
    print("palin")
else:
    print("not palin")
# Out:
# enter a stringmadam
# palin

# %%
# dir(str)
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
s1.capitalize()
# Out:
# 'Python workshop'

# %%
s2="HELLO"
s2.capitalize()
# Out:
# 'Hello'

# %%
s2.casefold()
#s2.count()
# Out:
# 'hello'

# %%
s2.count("h")
# Out:
# 0

# %%
s2.count("H")
# Out:
# 1

# %%
s3=s2.encode()
s3=s3.decode()
s3
# Out:
# 'HELLO'

# %%
s3.swapcase()
# Out:
# 'hello'

# %%
s4="vAudhA"
s4
s4.swapcase()
# Out:
# 'VaUDHa'

# %%
s4.startswith('v')
# Out:
# True

# %%
s4.startswith('V')
# Out:
# False

# %%
s4.endswith('u')
# Out:
# False

# %%
s4.find(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-578fee8de88f> in <module>
# ----> 1 s4.find(d)
#
# TypeError: must be str, not int

# %%
print("welcome {1}, iam from {0}".format("siri",'kadapa'))
# Out:
# welcome kadapa, iam from siri

# %%
print("hi %s hello %s"%("siri","siri"))
# Out:
# hi siri hello siri

# %%
s1="hello"
s1.isalpha()
s1.isdigit()
s2="45"
s2.isdigit()
# Out:
# True

# %%
s4
s4.lower()
s4.upper()
s4.islower()
s4.isupper()
s5="drgf"
s5.islower()
# Out:
# True

# %%
s5.replace("drgf","siri")
# Out:
# 'siri'

# %%
s5
# Out:
# 'drgf'

# %%
s1=" ghfhfqggqu gggg jg "
s1.rstrip()
s1.lstrip()
s1.split()
# Out:
# [' ghfhfqggqu gggg jg ']

# %%
s6="yvh#hknfdvin#hj"
s6.split('#')
# Out:
# ['yvh', 'hknfdvin', 'hj']

# %% [markdown]
# ## Functions
# - reusability is main moto
# - block of statements
#
# ### Types of functions
# - predefined
# - user defined

# %%
a=[1,32,9,5,7,2]
a=sorted(a)
max(a)
a,a[len(a)-2]
a=sorted(a,reverse=True)
a
# Out:
# [32, 9, 7, 5, 2, 1]

# %%
sum(a)
# Out:
# 56

# %%
chr(97)
chr(42)
# Out:
# '*'
